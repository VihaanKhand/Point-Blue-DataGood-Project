# %%
import sqlite3
con = sqlite3.connect("UAVSurveys.db")

# %%
cur = con.cursor()

# %%
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect("UAVSurveys.db")

# Query to get all table names
query = "SELECT name FROM sqlite_master WHERE type='table';"

# Execute the query and fetch all results
cursor = conn.cursor()
cursor.execute(query)
tables = cursor.fetchall()

# Print the list of tables
for table in tables:
    table_name = table[0]
    print(f"Accessing table: {table_name}")

    # Load the data from the table into a DataFrame
    df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)

    # Print the first few rows of each table
    print(df.head(), '\n')
# Out:
# Accessing table: Routes
# Empty DataFrame
# Columns: [RouteId, SurveyId, PlannedDuration, Pilot, UAV, StartTime, EndTime, Notes]
# Index: []
#
# Accessing table: sqlite_sequence
#               name  seq
# 0  LabelsClassSets    2
#
# Accessing table: LabelClasses
#               LabelClassName                       LabelClassDesc
# 0                     ADPE_a  Adult Adelie sitting on a territory
# 1  ADPE_a+ADPE_aStand+NoADPE         Adult Adelies and no Adelies
#
# Accessing table: LabelsClassSets
#    LabelClassSetId               LabelClassId
# 0                1                     ADPE_a
# 1                2  ADPE_a+ADPE_aStand+NoADPE
#
# Accessing table: Models
#                  ModelName ModelDateCreated ModelAlgorthim LabelClassSetId  \
# 0  ADPE_20231024_adult_sit       2023-10-24        YOLO V5               1
#
#   ModelTrainData ModelNotes
# 0           None       None
#
# Accessing table: Locations
#             Location LocationId Latitude Longitude
# 0       Cape Crozier       CROZ     None      None
# 1         Cape Royds       ROYD     None      None
# 2          Cape Bird       BIRD     None      None
# 3          Mono Lake       MONO     None      None
# 4  Five Springs Farm       FSPR     None      None
#
# Accessing table: UAVs
#        ModelName Manufacturer
# 0    Matrice 100          DJI
# 1      Phantom 4          DJI
# 2       Mavic 3E          DJI
# 3  Phantom 4 Pro          DJI
#
# Accessing table: SurveyImagery
#                              OrthomosaicName              SurveyId Stitched  \
# 0  bird_mid_south_adpe_2021-12-03_lcc169.tif  bird_adpe_2021-12-02        Y
# 1      bird_north_adpe_2021-12-02_lcc169.tif  bird_adpe_2021-12-02        Y
# 2        bird_mid_adpe_2022-11-26_lcc169.tif  bird_adpe_2022-11-26        Y
# 3      bird_north_adpe_2022-11-26_lcc169.tif  bird_adpe_2022-11-26        Y
# 4      bird_south_adpe_2022-11-26_lcc169.tif  bird_adpe_2022-11-26        Y
#
#   InDejuPenguinSci Tiled                              TilesLoc TileXDimension  \
# 0                Y     Y  PenguinCounting/bird_20211202/tiles/           None
# 1                Y     Y  PenguinCounting/bird_20211202/tiles/           None
# 2                Y     Y  PenguinCounting/bird_20221126/tiles/           None
# 3                Y     Y  PenguinCounting/bird_20221126/tiles/           None
# 4                Y     Y  PenguinCounting/bird_20221126/tiles/           None
#
#   TileYDimension GeoRefTableName OrthoProjection OrthoXResolution  \
# 0           None            None            None             None
# 1           None            None            None             None
# 2           None            None            None             None
# 3           None            None            None             None
# 4           None            None            None             None
#
#   OrthoYResolution                                     Notes
# 0             None  GB re-tiled, renamed, reposted 3/21/2024
# 1             None  GB re-tiled, renamed, reposted 3/21/2024
# 2             None  GB re-tiled, renamed, reposted 3/21/2024
# 3             None  GB re-tiled, renamed, reposted 3/21/2024
# 4             None  GB re-tiled, renamed, reposted 3/21/2024
#
# Accessing table: ManualCountsChick
#    Year              SurveyId Colony  SurveyDate FirstChickCt FirstInitials  \
# 0  2019  croz_adpe_2019-01-13   croz  2019-01-13
# 1  2020  croz_adpe_2020-01-12   croz  2020-01-12         5994            PL
# 2  2021  croz_adpe_2021-01-12   croz  2021-01-12         5846            PL
# 3  2022  croz_adpe_2022-01-12   croz  2022-01-12
# 4  2023  croz_adpe_2023-01-12   croz  2023-01-12         4919           AYL
#
#   ReviewChickCt ReviewInitials FinalChickCt  \
# 0
# 1          6362             NS
# 2          6054             AS
# 3
# 4
#
#                         CountedOrtho  \
# 0
# 1   croz_adpe_2020-01-12_wgs84_m.tif
# 2   croz_adpe_2021-01-12_wgs84_m.tif
# 3   croz_adpe_2022-01-12_wgs84_m.tif
# 4  croz_adpe_2023-01-12_lcc169_m.tif
#
#                                                Notes  \
# 0
# 1
# 2
# 3
# 4  Original AYL count was 6148, removed 1229 bird...
#
#                    OrthomosaicName
# 0  croz_adpe_2019-01-13_lcc169.tif
# 1  croz_adpe_2020-01-12_lcc169.tif
# 2                             None
# 3                             None
# 4  croz_adpe_2023-01-12_lcc169.tif
#
# Accessing table: ManualCountsOccupied
#    Year              SurveyId Colony  SurveyDate  FirstOccupiedCt  \
# 0  2018  croz_adpe_2018-11-29   croz  2018-11-29             6089
# 1  2019  croz_adpe_2019-12-02   croz  2019-12-02             6143
# 2  2020  croz_adpe_2020-11-29   croz  2020-11-29             6346
# 3  2021  croz_adpe_2021-11-27   croz  2021-11-27             5340
# 4  2022  croz_adpe_2022-12-02   croz  2022-12-02             4554
#
#   FirstInitials  StandingOccupiedCt  ReviewOccupiedCt ReviewInitials  \
# 0            CB                 172                12            NJS
# 1           AMC                 352                74             CB
# 2           AMC                 283                61             CB
# 3           AYL                 355               176             CB
# 4       AYL/AMC                 166              -114             CB
#
#    FinalOccupiedCt                       CountedOrtho  \
# 0             6101   croz_adpe_2018-11-29_wgs84_m.tif
# 1             6217   croz_adpe_2019-12-02_wgs84_m.tif
# 2             6407   croz_adpe_2020-11-29_wgs84_m.tif
# 3             5517   croz_adpe_2021-11-27_wgs84_m.tif
# 4             4440  croz_adpe_2022-12-02_lcc169_m.tif
#
#                                                Notes  \
# 0
# 1
# 2
# 3
# 4  AS: looks like different version used for manu...
#
#                    OrthomosaicName
# 0  croz_adpe_2018-11-29_lcc169.tif
# 1  croz_adpe_2019-12-02_lcc169.tif
# 2  croz_adpe_2020-11-29_lcc169.tif
# 3  croz_adpe_2021-11-27_lcc169.tif
# 4  croz_adpe_2022-12-02_lcc169.tif
#
# Accessing table: HumanLabels
#                SurveyId  LabelsClassSetId  ValidationTilesNum  \
# 0  croz_adpe_2019-12-02                 1                 200
# 1  croz_adpe_2020-11-29                 1                 200
# 2  croz_adpe_2021-11-27                 1                 200
# 3  bird_adpe_2022-11-26                 1                 200
# 4  croz_adpe_2022-12-02                 1                 200
#
#    ValidationLabelsNum                                ValidationLabelsLoc  \
# 0               1585.0  Z:\Informatics\S031\analyses\RI_penguin_count_...
# 1                817.0  Z:\Informatics\S031\analyses\RI_penguin_count_...
# 2               1127.0  Z:\Informatics\S031\analyses\RI_penguin_count_...
# 3                252.0  Z:\Informatics\S031\analyses\RI_penguin_count_...
# 4                634.0  Z:\Informatics\S031\analyses\RI_penguin_count_...
#
#   ValidInitials TrainingTilesNum TrainingLabelsNum TrainingLabelsLoc  \
# 0            CB             None              None              None
# 1            CB             None              None              None
# 2            CB             None              None              None
# 3            AS             None              None              None
# 4            AS             None              None              None
#
#   TestTilesNum TestLabelsNum TestLabelsLoc
# 0         None          None          None
# 1         None          None          None
# 2         None          None          None
# 3         None          None          None
# 4         None          None          None
#
# Accessing table: ModelPredictions
#                SurveyId                  OrthomosaicName  SeasonYr  \
# 0  croz_adpe_2022-12-02  croz_adpe_2022-12-02_lcc169.tif      2022
# 1  croz_adpe_2020-11-29  croz_adpe_2020-11-29_lcc169.tif      2020
# 2  croz_adpe_2019-12-02  croz_adpe_2019-12-02_lcc169.tif      2019
# 3  croz_adpe_2021-11-27  croz_adpe_2021-11-27_lcc169.tif      2021
# 4  croz_adpe_2018-11-29  croz_adpe_2018-11-29_lcc169.tif      2018
#
#                  ModelName PredictionLabelsLoc ConsolidatedPredictionsLoc  \
# 0  ADPE_20231024_adult_sit
# 1  ADPE_20231024_adult_sit
# 2  ADPE_20231024_adult_sit
# 3  ADPE_20231024_adult_sit
# 4  ADPE_20231024_adult_sit
#
#   DeDuplicated DeDuplictionMethod  Precision  Recall  F1Score  Threshold  \
# 0                                     0.9685  0.9227   0.9451       0.59
# 1                                     0.9488  0.9535   0.9512       0.56
# 2                                     0.9725  0.9382   0.9550       0.66
# 3                                     0.9777  0.9343   0.9555       0.64
# 4                                     0.9301  0.9218   0.9260       0.53
#
#    CorrectionFact Masked MaskedMethod  AdultCount  \
# 0          1.0497      T        d3mv5      170256
# 1          0.9951      T        d3mv5      246017
# 2          1.0366      T        d3mv5      226953
# 3          1.0464      T        d3mv5      211925
# 4          1.0090      T        d3mv5      226850
#
#                                  Notes
# 0    170256 masked and cleaned at 0.59
# 1  confirmed 4/26/24 at threshold 0.56
# 2  confirmed 4/26/24 at threshold 0.66
# 3  confirmed 5/16/24 at threshold 0.64
# 4  confirmed 4/26/24 at threshold 0.53
#
# Accessing table: GroundCounts
#     col season        date subcol  active_ct  occ_ct  total_ct notes
# 0  croz   2018  2018-11-28     11       28.0    29.0      29.5
# 1  croz   2018  2018-11-28     12      358.0   366.0     379.0
# 2  croz   2018  2018-11-28     14       57.0    59.0      61.0
# 3  croz   2018  2018-11-28    14a      204.0   212.0     218.0
# 4  croz   2018  2018-11-28  16-22      163.5   169.5     172.5
#
# Accessing table: Surveys
#                SurveyId LocationId SurveyStartDate SurveyStartTime  \
# 0  croz_empe_2023-11-14       CREM      2023-11-14           16:39
# 1  croz_adpe_2022-12-02       CROZ      2022-12-01           14:36
# 2  croz_adpe_2022-01-12       CROZ      2022-01-12            None
# 3  croz_adpe_2019-12-02       CROZ      2019-12-02           14:59
# 4  croz_adpe_2018-11-29       CROZ      2018-11-29            None
#
#   SurveyEndDate SurveyEndTime  FlightMode LandingMode  SurveyAltitude  \
# 0    2023-11-14         16:45         GPS         RTH           105.0
# 1    2022-12-02         13:57  Autonomous      Manual            50.0
# 2    2022-01-12          None  Autonomous      Manual            50.0
# 3    2019-12-02         17:45  Autonomous      Manual            50.0
# 4    2018-12-01          None         GPS      Manual             NaN
#
#    SurveySpeed  ... ShutterSpeed  Aperture ImgFormat  GridSpace  EstOverlapX  \
# 0          9.0  ...       1000.0       9.0       JPG        NaN          NaN
# 1          5.0  ...       1000.0       8.0       JPG        NaN          NaN
# 2          5.0  ...       1000.0       8.0       JPG        NaN          NaN
# 3          NaN  ...       1000.0       8.0       JPG        NaN          NaN
# 4          NaN  ...          NaN       NaN       JPG        NaN          NaN
#
#    EstOverlapY   GSD                                   Pilots  Weather  \
# 0          NaN  None                            Grant Ballard     Fine
# 1          NaN  None   Megan Elrod, Dennis Jongsomjit, Amy Li     None
# 2          NaN  None  Megan Elrod, Suzie Winquist, Danny Khor     None
# 3          NaN  None                Annie Schmidt, Kunal Shah     None
# 4          NaN  None                          Spencer Niebuhr
#
#                                                Notes
# 0                    Flown as a test of new airframe
# 1                Flown on two days due to weather(?)
# 2                                               None
# 3  There may have been a 4th UAV in the mix, but ...
# 4                           Flown manually by UNAVCO
#
# [5 rows x 24 columns]
